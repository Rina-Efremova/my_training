# %% [markdown]
# ### Домашнее задание: Знакомство с Google Colab
#
# #### Цель задания:
# Научиться основным функциям и возможностям Google Colab, включая выполнение кода, работу с текстовыми ячейками и загрузку данных.
#
# #### Задание:
#
# 1. **Создание и настройка документа:**
#     - Создайте новый документ в Google Colab.
#     - Переименуйте документ в "Введение в Google Colab".
#
# 2. **Текстовые и кодовые ячейки:**
#     - Вставьте текстовую ячейку и напишите краткое введение о Google Colab.
#     - Вставьте новую кодовую ячейку и выполните следующий код, чтобы убедиться, что среда работает:
#       ```python
#       print("Hello, Google Colab!")
#       ```
#
# 3. **Основы Python:**
#     - Вставьте кодовую ячейку и напишите код для выполнения следующих задач:
#         - Создайте список из 10 случайных чисел.
#         - Напишите функцию, которая возвращает сумму чисел в списке.
#         - Вызовите функцию и выведите результат на экран.
#
# 4. **Работа с библиотеками:**
#     - Установите библиотеку `numpy` (если она не установлена):
#       ```python
#       !pip install numpy
#       ```
#     - Импортируйте библиотеку `numpy` и создайте массив из 20 случайных чисел.
#     - Вычислите среднее значение массива и выведите его на экран.
#
# 5. **Загрузка данных:**
#     - Загрузите любой CSV файл из интернета в ваш Google Colab.
#     - Используйте библиотеку `pandas` для чтения CSV файла и выведите первые 5 строк данных.
#
# 6. **Визуализация данных:**
#     - Установите библиотеку `matplotlib` (если она не установлена):
#       ```python
#       !pip install matplotlib
#       ```
#     - Постройте простой график на основе данных из вашего CSV файла.
#
# 7. **Использование генетических алгоритмов:**
#     - Скопируйте код генетического алгоритма из лекционного блокнота.
#     - Запустите его, изучите работу кода.
#     - Измените значение целевой переменной TARGET. Добейтесь (увеличивая при необходимости число итераций обучения) полного соответствия "нового индивида целевой переменной".
#
# 8. **Сохранение и совместное использование:**
#     - Сохраните ваш документ на Google Диске.
#     - Настройте доступ к документу для общего использования и отправьте ссылку вашему преподавателю.
#
#
#
# #### Критерии оценки:
#
# - Выполнение всех шагов задания.
# - Корректность и чистота кода.
# - Понятные и информативные текстовые ячейки.
# - Качество визуализации данных.
#
# #### Дополнительные ресурсы:
# - [Документация Google Colab](https://colab.research.google.com/notebooks/intro.ipynb)
# - [Документация NumPy](https://numpy.org/doc/)
# - [Документация pandas](https://pandas.pydata.org/pandas-docs/stable/)
# - [Документация Matplotlib](https://matplotlib.org/stable/contents.html)
#
# ---

# %% [markdown]
# #Подсказки, необходимые для выполнения работы, можно посмотреть ниже

# %% [markdown]
# ### 1. Создание и настройка документа
#
# **Это текстовая ячейка:**
# ```
# # Введение в Google Colab
#
# Google Colab — это бесплатная облачная платформа от Google для машинного обучения и анализа данных. Она позволяет выполнять код на Python в браузере с использованием облачных ресурсов.
# ```
#
# **Кодовая ячейка:**
# ```python
# print("Hello, Google Colab!")
# ```
#
# ### 2. Основы Python
#
# **Кодовая ячейка для создания списка и функции:**
# ```python
# import random
#
# # Создаем список из 10 случайных чисел
# random_numbers = [random.randint(1, 100) for _ in range(10)]
#
# # Функция для вычисления суммы чисел в списке
# def sum_of_numbers(numbers):
#     return sum(numbers)
#
# # Вызов функции и вывод результата
# result = sum_of_numbers(random_numbers)
# print("Список случайных чисел:", random_numbers)
# print("Сумма чисел в списке:", result)
# ```
#
# ### 3. Работа с библиотеками
#
# **Установка и импорт библиотеки numpy, создание массива и вычисление среднего значения:**
# ```python
# !pip install numpy
#
# import numpy as np
#
# # Создаем массив из 20 случайных чисел
# random_array = np.random.randint(1, 100, size=20)
#
# # Вычисляем среднее значение массива
# mean_value = np.mean(random_array)
# print("Массив случайных чисел:", random_array)
# print("Среднее значение массива:", mean_value)
# ```
#
# ### 4. Загрузка данных
#
# **Загрузка CSV файла и чтение данных с использованием pandas:**
# ```python
# !pip install pandas
#
# import pandas as pd
#
# # Загрузка CSV файла из интернета
# url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv'
# data = pd.read_csv(url)
#
# # Вывод первых 5 строк данных
# print(data.head())
# ```
#
# ### 5. Визуализация данных
#
# **Установка библиотеки matplotlib и построение графика:**
# ```python
# !pip install matplotlib
#
# import matplotlib.pyplot as plt
#
# # Предположим, что наш CSV файл имеет столбцы "Month" и "Passengers"
# # Построим график количества пассажиров по месяцам
# plt.figure(figsize=(10, 6))
# plt.plot(data['Month'], data[' "1958"'], marker='o', linestyle='-')
# plt.title('Количество пассажиров по месяцам в 1958 году')
# plt.xlabel('Месяц')
# plt.ylabel('Количество пассажиров')
# plt.grid(True)
# plt.show()
# ```
#
# ### 6. Сохранение и совместное использование
#
# **Сохранение документа выполняется через меню File -> Save a copy in Drive.**

# %% [markdown]
# # Введение в Google Colab
# Google Colab - это облачный сервис от Goodle, позволяющий писать и выполнять Python-код в браузере без установки дополнительных программ, поддерживая визуализацию, библиотеки и добавленных текстовых пояснений.

# %%
print("Hello", "Google Colab")
# Out:
# Hello Google Colab

# %%
import random

5, 12, 23, 34, 45, 56, 67, 78, 89, 99
random_numbers = [random.randint(1,100) for _ in range(10)]


def sum_of_numbers(numbers):
    return sum(numbers)

result = sum_of_numbers(random_numbers)
print("Список случайных чисел:", random_numbers)
print("Сумма чисел в списке:",result)
# Out:
# Список случайных чисел: [5, 32, 78, 15, 16, 73, 3, 4, 20, 89]
# Сумма чисел в списке: 335

# %%
# !pip install numpy

import numpy as np

1, 12, 23, 34, 45, 56, 67, 78, 89, 98, 87, 76, 65, 54, 43, 32, 21, 19, 37, 82
random_array = np.random.randint(1,100, size=200)

mean_value = np.mean(random_array)
print("Массив случайных чисел:", random_array)
print("Среднее значение массива:, mean_value")
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Массив случайных чисел: [46 66  1 57 56 70 43 26 87 69 97 80 94 40 50 79 61 38 16 19 33 26  8 67
#  45  9 29  4 62 99 76 58 49  4 74 82 93 86 16 45  7 74 10 24 47 69 56  3
#  10 20  7 18 44 76 29 78 72 35  5 97 55 80 65 95 77 55 78 34 31 22 65 54
#  17 53 63 38 10 21  6 96 18 34 11 20 78 75 63 31 11 17 70 18 24 69 81 65
#  61 31 95 56 16 25 24 59 62 32 33 70  2 55 65 56 84 94 22 17 42 17 94 55
#  45 45 61 51 89 90 69 97 87 38 49 81 66 68  4 97 89 99 45 19 78 99 19 29
#  42 54 53 57  6 90 76 96  7  1 20 65 79 63 65 35 76 88 10 39 48 76 29 32
#  83 46 57 69 37 32 82 15 92 56 40 65  1 80 86 17 44 74  5 37 87 32 76  4
#  63  9 91  4 72  3 54  5]
# Среднее значение массива:, mean_value

# %%
# !pip install pandas

import pandas as pd

ur1 = 'https://people.sc.fsu.edu/~jburkardt/data/csv/'
data = pd.read_csv(ur1)

print(data.head())
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#   <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# 0                                             <html>
# 1                                             <head>
# 2       <title>Index of /~jburkardt/data/csv</title>
# 3                                            </head>
# 4                                             <body>

# %%
from os import name
# !pip install matplotlib

import matplotlib.pyplot as plt

plt.figure(figsize=(45, 20))
plt.plot(data=['Degree'], name=['December'], marker='0', linestyle='-')
plt.title('Самый низкий градус зимой в декабре')
plt.xlabel('Декабрь')
plt.ylabel('Самый низкий градус')
plt.grid(True)
plt.show()
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# #Генетические алгоритмы

# %% [markdown]
# ##Что такое генетический алгоритм?
#
# Генетические алгоритмы — это тип алгоритма оптимизации и поиска, вдохновленный процессом естественного отбора в биологической эволюции.
#
# Эти алгоритмы используют такие принципы, как мутация, скрещивание (или воспроизводство) и отбор для поиска решений сложных проблем.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Джон Генри Холланд** – американский ученый, профессор электротехники и информатики в Мичиганском университете. Наиболее известен как инноватор сложных адаптивных систем и нелинейной науки, а также создатель генетических алгоритмов.
#
# Идею генетических алгоритмов он сформулировал и обосновал в конце 60-х-начале 70-х гг. ХХ в. Он заинтересовался свойствами процессов естественной эволюции, в том числе фактом, что эволюционируют хромосомы, а не сами существа. Ученый был уверен в возможности составить и реализовать в виде компьютерной программы алгоритм, который будет решать сложные задачи так, как это делает природа – путем эволюции. Поэтому он начал трудиться над алгоритмами, оперировавшими последовательностями двоичных цифр (единиц и нулей), получившими название хромосом.
#
# Генетические алгоритмы работают по аналогии с природой. Они оперируют с совокупностью «особей», представляющих собой строки, каждая из которых кодирует одно из решений задачи. Приспособленность особи оценивается с помощью специальной функции. Наиболее приспособленные получают шанс скрещиваться и давать потомство. Наихудшие особи удаляются. Таким образом, приспособленность нового поколения в среднем выше предыдущего. На практике генетические алгоритмы используются для решения таких, задач, как оптимизация запросов в базах данных, настройка и обучение искусственной нейронной сети, составление игровых стратегий, создание искусственной жизни. Вышедшая в 1975 г. книга Джона Холланда «Адаптация в естественных и искусственных системах» [Adaptation in Natural and Artificial Systems] является основополагающим трудом в этой области исследований

# %% [markdown]
# ##Population
# Это относится к набору возможных решений (или хромосом) проблемы. На каждой итерации (или поколении) генетические алгоритмы работают с популяцией хромосом.
#
# ##Fitness Function
# Эта функция измеряет качество или «пригодность» решения для популяции, направляя поиск оптимальных решений.
#
# ##Operators: Selection, Crossover, Mutation
# Эти операторы имитируют естественные эволюционные процессы. Отбор выбирает подходящих особей, скрещивание объединяет два решения для создания новых, а мутация вносит в решение небольшие случайные изменения.

# %%
import random

# Количество особей в каждом поколении
POPULATION_SIZE = 100

# Валидные гены
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Целевая строка для генерации
TARGET = "In principio erat Verbum 2000"

class Individual(object):
	'''
	Класс, представляющий отдельную особь (индивида) в популяции
	'''
	def __init__(self, chromosome):
		self.chromosome = chromosome
		self.fitness = self.cal_fitness()

	@classmethod
	def mutated_genes(self):
		'''
		Создаем случайные гены для мутации
		'''
		global GENES
		gene = random.choice(GENES)
		return gene

	@classmethod
	def create_gnome(self):
		'''
		Создаем хромосому или набор генов
		'''
		global TARGET
		gnome_len = len(TARGET)
		return [self.mutated_genes() for _ in range(gnome_len)]

	def gene_transfer(self, par2):
		'''
		Передаем гены новому поколению индивидов
		'''

		child_chromosome = []
		for gp1, gp2 in zip(self.chromosome, par2.chromosome):

			prob = random.random()

			# если вероятность меньше 0,50, берем ген
			# от родителя 1
			if prob < 0.45:
				child_chromosome.append(gp1)

			# если вероятность между 0.50 и 0.95, берем
			# ген от родителя 2
			elif prob < 0.90:
				child_chromosome.append(gp2)

			# в противном случае берем случайный ген (мутация),
			else:
				child_chromosome.append(self.mutated_genes())


		return Individual(child_chromosome)

	def cal_fitness(self):
		'''
		Рассчитываем показатель соответствия, это количество
		символов в строке, которые отличаются от целевой
		строки.
		'''
		global TARGET
		fitness = 0
		for gs, gt in zip(self.chromosome, TARGET):
			if gs != gt: fitness+= 1
		return fitness

# Driver code
def main():
	global POPULATION_SIZE

	#Текущее поколение
	generation = 1

	found = False
	population = []

	# Новое поколение
	for _ in range(POPULATION_SIZE):
				gnome = Individual.create_gnome()
				population.append(Individual(gnome))

	while not found:

		# Отсортируем популяцию в порядке возрастания оценки соответствия целевой функции
		population = sorted(population, key = lambda x:x.fitness)

		# Если у нас появился индивид, достигший целевой функции
		# цикл совершенствования можно прервать
		if population[0].fitness <= 0:
			found = True
			break

		# В противном случае - продолжаем создавать новые поколения
		new_generation = []

		# Определяем 10% популяции, наиболее соответствующих целевой фукнции
		# чтобы передать их гены будущим поколениям
		s = int((10*POPULATION_SIZE)/100)
		new_generation.extend(population[:s])


		s = int((90*POPULATION_SIZE)/100)
		for _ in range(s):
			parent1 = random.choice(population[:50])
			parent2 = random.choice(population[:50])
			child = parent1.gene_transfer(parent2)
			new_generation.append(child)

		population = new_generation

		print("Generation: {}\tString: {}\tFitness: {}".
			format(generation,
			"".join(population[0].chromosome),
			population[0].fitness))

		generation += 1


	print("Generation: {}\tString: {}\tFitness: {}".
		format(generation,
		"".join(population[0].chromosome),
		population[0].fitness))

if __name__ == '__main__':
	main()
# Out:
# Generation: 1	String: lR$ 7Ozv--iXDHcV8)mkF0AoD2Dxq	Fitness: 27
# Generation: 2	String: 1 Dp)V6!iv3]I;#Gpms Hxym3w=fT	Fitness: 26
# Generation: 3	String: DcApthnniOeo30H"fgUZ Z
# Y3LzY$	Fitness: 25
# Generation: 4	String: xc ptKnniOeo3wT{f&dR x
# v,=z7$	Fitness: 24
# Generation: 5	String: [ bptinni@3oI0#ZpmU jZ
# m3LKYS	Fitness: 23
# Generation: 6	String: xc p)inni@;o3Ag{fD.5 xsZ}=z70	Fitness: 22
# Generation: 7	String: xc@p)inni@;oV&g5fmU5Dxsm LzY0	Fitness: 21
# Generation: 8	String: xc@p)inni@;oV&g5fmU5Dxsm LzY0	Fitness: 21
# Generation: 9	String: I  paiK_i@ioDjHafMU1DvAm3G0Yv	Fitness: 19
# Generation: 10	String: Ig@p)inq}iJo;&ga;Dt5&5sm 20Y0	Fitness: 18
# Generation: 11	String: Ig@p)inq}iJo;&ga;Dt5&5sm 20Y0	Fitness: 18
# Generation: 12	String: I" ptinqiiJoIBgaNRmSavsm 20A@	Fitness: 17
# Generation: 13	String: I{ paKnci1io fga;q]Y
# %Am w0"i	Fitness: 16
# Generation: 14	String: I{ paKnci1io fga;q]Y
# %Am w0"i	Fitness: 16
# Generation: 15	String: I( p)inciyio$t4aoD]R
# %$m w0"0	Fitness: 15
# Generation: 16	String: I( p)inciyio$t4aoD]R
# %$m w0"0	Fitness: 15
# Generation: 17	String: I1 painyiiio :HatR]Yl%sm w0"0	Fitness: 14
# Generation: 18	String: I1 painyiiio :HatR]Yl%sm w0"0	Fitness: 14
# Generation: 19	String: I1 painyiiio :HatR]Yl%sm w0"0	Fitness: 14
# Generation: 20	String: IJ p)incVyTo k;otDMRr9sm 2000	Fitness: 13
# Generation: 21	String: IJ p)incVyTo k;otDMRr9sm 2000	Fitness: 13
# Generation: 22	String: I1 paineiCio :HatRUY
# %sm 2000	Fitness: 12
# Generation: 23	String: I1 paineiCio :HatRUY
# %sm 2000	Fitness: 12
# Generation: 24	String: IJ painciOio k;at UR
# 9Am 20f0	Fitness: 11
# Generation: 25	String: IJ painciOio k;at UR
# 9Am 20f0	Fitness: 11
# Generation: 26	String: IJ painciOio k;at UR
# 9Am 20f0	Fitness: 11
# Generation: 27	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 28	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 29	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 30	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 31	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 32	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 33	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 34	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 35	String: IJ pLinciOio k;at ]2rbsm 20f0	Fitness: 9
# Generation: 36	String: I( puincipio D;at h2rbAm52000	Fitness: 8
# Generation: 37	String: I( puincipio D;at h2rbAm52000	Fitness: 8
# Generation: 38	String: I( puincipio D;at h2rbAm52000	Fitness: 8
# Generation: 39	String: I( puincipio D;at h2rbAm52000	Fitness: 8
# Generation: 40	String: I
#  p)incipio D}at V2rbA: 2000	Fitness: 7
# Generation: 41	String: I
#  p)incipio D}at V2rbA: 2000	Fitness: 7
# Generation: 42	String: I
#  p)incipio D}at V2rbA: 2000	Fitness: 7
# Generation: 43	String: I
#  p)incipio D}at V2rbA: 2000	Fitness: 7
# Generation: 44	String: I
#  p)incipio D}at V2rbA: 2000	Fitness: 7
# Generation: 45	String: I
#  p)inci3io D}at V2rbum 2000	Fitness: 6
# Generation: 46	String: I
#  p)inci3io D}at V2rbum 2000	Fitness: 6
# Generation: 47	String: I
#  p)inci3io D}at V2rbum 2000	Fitness: 6
# Generation: 48	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 49	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 50	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 51	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 52	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 53	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 54	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 55	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 56	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 57	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 58	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 59	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 60	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 61	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 62	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 63	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 64	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 65	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 66	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 67	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 68	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 69	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 70	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 71	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 72	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 73	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 74	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 75	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 76	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 77	String: I
#  p)incipio D}at V)rbum 2000	Fitness: 5
# Generation: 78	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 79	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 80	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 81	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 82	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 83	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 84	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 85	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 86	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 87	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 88	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 89	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 90	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 91	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 92	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 93	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 94	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 95	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 96	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 97	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 98	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 99	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 100	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 101	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 102	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 103	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 104	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 105	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 106	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 107	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 108	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 109	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 110	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 111	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 112	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 113	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 114	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 115	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 116	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 117	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 118	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 119	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 120	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 121	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 122	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 123	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 124	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 125	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 126	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 127	String: I
#  p)incipio D}at Verbum 2000	Fitness: 4
# Generation: 128	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 129	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 130	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 131	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 132	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 133	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 134	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 135	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 136	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 137	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 138	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 139	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 140	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 141	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 142	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 143	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 144	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 145	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 146	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 147	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 148	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 149	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 150	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 151	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 152	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 153	String: I5 p)incipio Wrat Verbum 2000	Fitness: 3
# Generation: 154	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 155	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 156	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 157	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 158	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 159	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 160	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 161	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 162	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 163	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 164	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 165	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 166	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 167	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 168	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 169	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 170	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 171	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 172	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 173	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 174	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 175	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 176	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 177	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 178	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 179	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 180	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 181	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 182	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 183	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 184	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 185	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 186	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 187	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 188	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 189	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 190	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 191	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 192	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 193	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 194	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 195	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 196	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 197	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 198	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 199	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 200	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 201	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 202	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 203	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 204	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 205	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 206	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 207	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 208	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 209	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 210	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 211	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 212	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 213	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 214	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 215	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 216	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 217	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 218	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 219	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 220	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 221	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 222	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 223	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 224	String: IQ p)incipio erat Verbum 2000	Fitness: 2
# Generation: 225	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 226	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 227	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 228	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 229	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 230	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 231	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 232	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 233	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 234	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 235	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 236	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 237	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 238	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 239	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 240	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 241	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 242	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 243	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 244	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 245	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 246	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 247	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 248	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 249	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 250	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 251	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 252	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 253	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 254	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 255	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 256	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 257	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 258	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 259	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 260	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 261	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 262	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 263	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 264	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 265	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 266	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 267	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 268	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 269	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 270	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 271	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 272	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 273	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 274	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 275	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 276	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 277	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 278	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 279	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 280	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 281	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 282	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 283	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 284	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 285	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 286	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 287	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 288	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 289	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 290	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 291	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 292	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 293	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 294	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 295	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 296	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 297	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 298	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 299	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 300	String: In p)incipio erat Verbum 2000	Fitness: 1
# Generation: 301	String: In principio erat Verbum 2000	Fitness: 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
